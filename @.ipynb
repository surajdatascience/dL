# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('./Titanic.csv')

# %%
df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
plt.figure(figsize=(4,3))
sns.kdeplot(data=df)
plt.show()

# %%
for i in df.columns:
    if df[i].dtypes!='object':
        sns.boxplot(y=df[i])
        plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(data=df,y='Fare')
plt.show()

# %%
plt.show()

# %%
sns.heatmap(pclass_surv,annot=True,fmt="d")
plt.show()

# %%
df2=[[df.Pclass[0:25],df.Fare[0:25]]] # sort values

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Fare_Range'],
#       dtype='object')

# %%
df1=df[['PassengerId', 'Survived']]

# %%
sns.boxplot(data=df,x="Fare")
plt.show()
